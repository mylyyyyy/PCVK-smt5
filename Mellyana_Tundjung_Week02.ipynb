# %% [markdown]
# <a href="https://colab.research.google.com/github/mylyyyyy/PCVK-smt5/blob/main/Mellyana_Tundjung_Week02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #NAMA : MELLYANA TUNDJUNG
# #NIM : 2141720061
# #KELAS : TI-3B

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #**PRAKTIKUM**

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
img = cv.imread('/content/drive/MyDrive/Fotokuu/Gjgj/logo.jpg')
plt.imshow(img)

# %%
img2 = img
img2 = cv.cvtColor(img2,cv.COLOR_BGR2RGB)
plt.imshow(img2)

# %%
img_gray = cv.imread('/content/drive/MyDrive/Fotokuu/Gjgj/logo.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray,cmap ='gray')

# %%
plt.imshow(img_gray,cmap ='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB),(512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,(384,0),(510,150),(0,255,0),10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,(200,200),(300,300),(0,0,255),15)
plt.imshow(black_img)

# %%
cv.circle(black_img,(100,100),50,(255,0,0),8)
plt.imshow(black_img)

# %%
cv.circle(black_img,(400,400),50,(255,0,0),-1)
cv.line(black_img,(0,0),(512,512),(255,255,255),5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,'Hello',(10,500),font,4,(255,255,0),2,cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2 = np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices =np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# ## Pertanyaan
# 1. Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?
#
#
# > Pada gambar yang ditampilkan dengan matplotlib perbedannya ialah pada matplotlib terdapat koordinat yang memudahkan identifikasi tata letak suatu area/pixel pada gambar, kemudian perbedaan lainnya ialah matplotlib menggunakan format RGB sedangkan cv2 menggunakan BGR jadi perlu dikonversikan agar warna yang ditampilkan pada matplotlib sama seperti aslinya
#
# 2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16
# dan int32?
#
# > Untuk perbedaannya dari segi tampilan tidak berpengaruh dikarenakan hanya menampilkan gambar hitam saja, namun apabila digunakan pada gambar lain mungkin dari segi penampilan akan berbeda, perbedaan lain yang signifikan adalah pada ukuran dari np array tersebut, jika menggunakan int32 otomatis akan lebih besar ukuran penyimpanannya dikarenakan ukuran/range dari int32 yang besar.
#
# 3. Apakah kegunaan “google.colab.patches import cv2_imshow” pada potongan kode
# berikut
#
# > Kegunaan dari line code tersebut sebenarnya hanya dikhususkan untuk google colab saja, fungsinya untuk membenarkan bug yang terjadi ketika dilakukan penampilan gambar menggunakan imshow di google colab karena Colab memiliki cara yang unik untuk menampilkan gambar.
#
# 4. Apakah kegunaan “skimage import io” pada potongan kode soal nomor 3
#
# > Modul io dalam scikit-image adalah bagian dari pustaka yang menyediakan berbagai fungsi untuk membaca, menulis, dan menampilkan gambar. pada praktikum ini tidak digunakan karena menggunakan cv2 saja, namun pada praktikum sebelumnya pada week01 io digunakan untuk mengambil gambar dari urls.

# %% [markdown]
# #**TUGAS**

# %% [markdown]
# ###1. Dengan menggunakan figsize, perhatikan apakah ukuran image pixelnya juga berubah?

# %%
kat = cv.cvtColor(cv.imread('/content/drive/MyDrive/Fotokuu/Gjgj/Aku.jpg'),cv.COLOR_BGR2RGB)
plt.imshow(kat)
print(kat.shape)
# Out:
# (1600, 1200, 3)

# %%
fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(111)
ax.imshow(kat)
print(kat.shape)
# Out:
# (1600, 1200, 3)

# %% [markdown]
# #### JAWAB
# Tidak, merubah ukuran figsize hanya merubah ukuran tampilan saja, untuk struktur pixelnya tetaplah sama

# %% [markdown]
# ###2.Tampilkan image dalam channel Red-Blue dan Green-Blue saja!

# %%
red_blue_image = kat.copy()
red_blue_image[:, :, 1] = 0  # Set the green channel to zero
print("red-blue")
plt.imshow(red_blue_image)
# Out:
# red-blue

# %%
green_blue_image = kat.copy()
green_blue_image[:, :, 2] = 0  # Set the red channel to zero
print("green-blue")
plt.imshow(green_blue_image)
# Out:
# green-blue

# %% [markdown]
# ###3.Tampilkan image baris ke 20-115, kolom 25-120!

# %%
cropped_image = kat[20:116, 25:121]
print("image baris ke 20-115, kolom 25-120")
plt.imshow(cropped_image)
# Out:
# image baris ke 20-115, kolom 25-120

# %% [markdown]
# ###4.Tampilkan image baris ke 5-30, semua kolom, channel Red saja!

# %%
cropped_image2 = kat[5:31,:]
print("image baris ke 5-30, semua kolom, channel Red saja")
plt.imshow(cropped_image2[:, :, 0],cmap="Reds")
# Out:
# image baris ke 5-30, semua kolom, channel Red saja

# %% [markdown]
# ###5.Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image. disarankan menggunakan bilangan acak/random!

# %%
import random
width, height = 400, 400
katkat = kat.copy()
for _ in range(5):
    x1, y1 = random.randint(50, width - 50), random.randint(50, height - 50)
    x2, y2 = x1 + random.randint(20, 100), y1 + random.randint(20, 100)
    color = (random.randint(0, 255), random.randint(0, 255), random.randint(0, 255))
    cv.rectangle(katkat, (x1, y1), (x2, y2), color, -1)  # Kotak diisi dengan warna

plt.imshow(katkat)

# %% [markdown]
# ###6.Tampilkan image dengan posisi terbalik!

# %%
cat_flip = cv.flip(kat,0)
plt.imshow(cat_flip)

# %% [markdown]
# ###Berdasarkan praktikum bagian 3 dan 4 kerjakan beberapa tugas berikut :
# ###7. Buat rectangle dan circle pada bagian wajah dari image foto anda saat beraktifitas (bukan pasfoto).

# %%
foto = cv.cvtColor(cv.imread('/content/drive/MyDrive/Fotokuu/Gjgj/logo.jpg'),cv.COLOR_BGR2RGB)

# %%
foto2 = foto.copy()
cv.circle(foto,(970,330),150,(255,0,0),8)
plt.subplot(1, 2, 1)
plt.imshow(foto)
cv.rectangle(foto2,(850,200),(1100,500),(255,255,0),8)
plt.subplot(1, 2, 2)
plt.imshow(foto2)

# %% [markdown]
# ###8. Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB dari citra kitten/ lena/ mandrill/ male/ female/ couple/ sailboat/ peppers!

# %%
#Using kat image
kat_rect=kat.copy()
cv.rectangle(kat_rect,(0,400),(100,300),(255,255,0),10)
plt.imshow(kat_rect[:, :, 2],cmap="Blues")

# %% [markdown]
# ###9. Lengkapi tulisan nama file pada file citra dari soal no.8. gunakan font, ukuran font, dan warna font yang sesuai keinginan anda.

# %%
cv.putText(kat_rect,text='kitten2.jpg',org=(100,100),fontFace=font,fontScale=1.5,color=(0,0,0),thickness=8,lineType=cv.LINE_AA)
plt.imshow(kat_rect[:, :, 2],cmap="Blues")

# %% [markdown]
# ###10. Tunjukkan code program anda pada bapak/ibu dosen

# %% [markdown]
# ##**TUGAS KELOMPOK 8**
# ###Kelompok 8 tutup bagian kabupaten dan tanggal dikeluarkan KTP yang ada dibagian bawah foto.

# %%
ktp = cv.cvtColor(cv.imread('/content/drive/MyDrive/dummyktp.png'),cv.COLOR_BGR2RGB)
cv.rectangle(ktp,(250, 30),(560,55),(255,255,0),-1)
cv.rectangle(ktp,(620, 365),(728,380),(255,255,0),-1)
plt.imshow(ktp)
